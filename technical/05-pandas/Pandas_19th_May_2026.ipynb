# %%
cart = {"apple": 3, "banana": 5}
cart["orange"] = 2
print(len(cart))

# %%
cart = {"apple": 3, "banana": 5}

# %%
cart
# Out:
# {'apple': 3, 'banana': 5}

# %%
cart["orange"] = 2

# %%
cart
# Out:
# {'apple': 3, 'banana': 5, 'orange': 2}

# %%
len(cart)
# Out:
# 3

# %%
cart.get("apple")
# Out:
# 3

# %%
cart.get("kiwi", "not available")
# Out:
# 'not available'

# %%
total = 0
for i in range(1, 5):
    total += i
print(total)

# %%
total = 0
for i in range(1, 5):
    total = total + i
print(total)
# Out:
# 10

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
print(arr.shape)
# Out:
# (5,)

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/churn_data.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# ...

# %% [markdown]
# - Churn = No: The customer is active. The customer has not left the services
# - Churn = Yes: The customer is inactive. The customer has left using the services.

# %%
df.head()
# by defult you get top 5 rows
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df.head(10)
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
# 5  9305-CDSKC       8          Yes  Month-to-month              Yes
# 6  1452-KIOVK      22          Yes  Month-to-month              Yes
# 7  6713-OKOMC      10           No  Month-to-month               No
# 8  7892-POOKP      28          Yes  Month-to-month              Yes
# 9  6388-TABGU      62          Yes        One year               No
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# ...

# %%
df.tail()
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 7038               Mailed check           84.80       1990.5    No
# 7039    Credit card (automatic)          103.20       7362.9    No
# 7040           Electronic check           29.60       346.45    No
# 7041               Mailed check           74.40        306.6   Yes
# 7042  Bank transfer (automatic)          105.65       6844.5    No

# %%
df.tail(10)
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 7033  9767-FFLEM      38          Yes  Month-to-month              Yes
# 7034  0639-TSIQW      67          Yes  Month-to-month              Yes
# 7035  8456-QDAVC      19          Yes  Month-to-month              Yes
# 7036  7750-EYXWZ      12           No        One year               No
# 7037  2569-WGERO      72          Yes        Two year              Yes
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 7033    Credit card (automatic)           69.50      2625.25    No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 495.3+ KB

# %% [markdown]
# - object === string/text
# - int
# - float
# - bool
# - datetime

# %%
df
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# ...

# %%
df.shape
# number of rows and columns
# Out:
# (7043, 9)

# %%
df.columns
# Out:
# Index(['customerID', 'tenure', 'PhoneService', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %% [markdown]
# - df.head()
# - df.tail()
# - df.info()
# - df.shape
# - df.columns
# - df.index

# %% [markdown]
# **Filter**

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df["Churn"]
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %%
df[["Churn", "tenure"]]
# Out:
#      Churn  tenure
# 0       No       1
# 1       No      34
# 2      Yes       2
# 3       No      45
# 4      Yes       2
# ...    ...     ...
# 7038    No      24
# 7039    No      72
# 7040    No      11
# 7041   Yes       4
# 7042    No      66
#
# [7043 rows x 2 columns]

# %% [markdown]
# - = : Assignment
# - ==: Comparison

# %%
a = 1
a == 1
# Out:
# True

# %%
df["Churn"] == "Yes"
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041     True
# 7042    False
# Name: Churn, Length: 7043, dtype: bool

# %%
df[df["Churn"] == "Yes"]
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# 5     9305-CDSKC       8          Yes  Month-to-month              Yes
# 8     7892-POOKP      28          Yes  Month-to-month              Yes
# 13    0280-XJGEX      49          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7021  1699-HPSBG      12          Yes        One year              Yes
# 7026  8775-CEBBJ       9          Yes  Month-to-month              Yes
# 7032  6894-LFHLY       1          Yes  Month-to-month              Yes
# 7034  0639-TSIQW      67          Yes  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# ...

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df['PhoneService'] == 'Yes'
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 7038     True
# 7039     True
# 7040    False
# 7041     True
# 7042     True
# Name: PhoneService, Length: 7043, dtype: bool

# %%
df[df['PhoneService'] == 'Yes'].shape
# Out:
# (6361, 9)

# %%
len(df[df['PhoneService'] == 'Yes'])
# Out:
# 6361

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %% [markdown]
# - Find number of customers using Mailed Check as the payment method

# %%
df['PaymentMethod'] == "Mailed check"
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7038     True
# 7039    False
# 7040    False
# 7041     True
# 7042    False
# Name: PaymentMethod, Length: 7043, dtype: bool

# %%
df[df['PaymentMethod'] == "Mailed check"].shape
# Out:
# (1612, 9)

# %% [markdown]
# **Multiple Conditions**

# %%
(df['Churn'] == 'No') & (df['PhoneService'] == 'Yes')
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 7038     True
# 7039     True
# 7040    False
# 7041    False
# 7042     True
# Length: 7043, dtype: bool

# %%
df[(df['Churn'] == 'No') & (df['PhoneService'] == 'Yes')].shape
# Out:
# (4662, 9)

# %%
df[(df['Churn'] == 'No') & (df['PhoneService'] == 'Yes')]['customerID'].nunique()
# Out:
# 4662

# %%
df1 = df[(df['Churn'] == 'No') & (df['PhoneService'] == 'Yes')]

# %%
df1['customerID'].nunique()
# Out:
# 4662

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %% [markdown]
# - Find the number of churn customer who left the company before 2 months of the tenure.

# %%
(df['Churn'] == 'Yes') & (df['tenure'] < 2)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Length: 7043, dtype: bool

# %%
df[(df['Churn'] == 'Yes') & (df['tenure'] < 2)].shape
# Out:
# (380, 9)

# %% [markdown]
# **Aggregate**
# - Group
# - Aggregate

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df.groupby("Churn").agg({"customerID": "count"})
# Out:
#        customerID
# Churn
# No           5174
# Yes          1869

# %%
df.groupby("Churn")

# %%
df.groupby("Churn").agg({"tenure":"mean", "customerID":"count"})
# Out:
#           tenure  customerID
# Churn
# No     37.569965        5174
# Yes    17.979133        1869

# %%
df.groupby("Churn").agg(avg_tenure=("tenure", "mean"), Count_of_customers=("customerID", "count"))
# Out:
#        avg_tenure  Count_of_customers
# Churn
# No      37.569965                5174
# Yes     17.979133                1869

# %%
df.groupby("Churn")['customerID'].count()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: customerID, dtype: int64

# %%
cust = pd.read_csv("/content/customer_data.csv")
cust.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df2 = pd.merge(df, cust, on = "customerID", how = "inner")

# %%
# final = pd.merge(df2, internet, on = , how = )

# %%
df2.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# 0           Electronic check           29.85        29.85    No  Female
# 1               Mailed check           56.95       1889.5    No    Male
# 2               Mailed check           53.85       108.15   Yes    Male
# 3  Bank transfer (automatic)           42.30      1840.75    No    Male
# 4           Electronic check           70.70       151.65   Yes  Female
#
#    SeniorCitizen Partner Dependents
# 0              0     Yes         No
# 1              0      No         No
# ...

# %% [markdown]
# - Which gender has a higher avg monthly charges?

# %%
df2.groupby("gender").agg({"MonthlyCharges":'mean'})
# Out:
#         MonthlyCharges
# gender
# Female       65.204243
# Male         64.327482

# %% [markdown]
# - Among all churn customers, which payment method was popular?

# %%
df['Churn']=='Yes'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041     True
# 7042    False
# Name: Churn, Length: 7043, dtype: bool

# %%
ch = df2[df2['Churn']=='Yes']
# ch =  the dataframe of all the churn customers

# %%
ch.head()
# Out:
#     customerID  tenure PhoneService        Contract PaperlessBilling  \
# 2   3668-QPYBK       2          Yes  Month-to-month              Yes
# 4   9237-HQITU       2          Yes  Month-to-month              Yes
# 5   9305-CDSKC       8          Yes  Month-to-month              Yes
# 8   7892-POOKP      28          Yes  Month-to-month              Yes
# 13  0280-XJGEX      49          Yes  Month-to-month              Yes
#
#                 PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# 2                Mailed check           53.85       108.15   Yes    Male
# 4            Electronic check           70.70       151.65   Yes  Female
# 5            Electronic check           99.65        820.5   Yes  Female
# 8            Electronic check          104.80      3046.05   Yes  Female
# 13  Bank transfer (automatic)          103.70       5036.3   Yes    Male
#
#     SeniorCitizen Partner Dependents
# 2               0      No         No
# ...

# %%
ch.groupby("PaymentMethod").agg({"customerID":"count"})
# Out:
#                            customerID
# PaymentMethod
# Bank transfer (automatic)         258
# Credit card (automatic)           232
# Electronic check                 1071
# Mailed check                      308

# %% [markdown]
# - Which Contract type is popular among those who are male and have not churned?

# %%
(df2['gender'] =='Male') & (df2['Churn'] == 'No')
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7038     True
# 7039    False
# 7040    False
# 7041    False
# 7042     True
# Length: 7043, dtype: bool

# %%
b = df[(df2['gender'] =='Male') & (df2['Churn'] == 'No')]

# %%
b.head()
# Out:
#     customerID  tenure PhoneService        Contract PaperlessBilling  \
# 1   5575-GNVDE      34          Yes        One year               No
# 3   7795-CFOCW      45           No        One year               No
# 6   1452-KIOVK      22          Yes  Month-to-month              Yes
# 9   6388-TABGU      62          Yes        One year               No
# 10  9763-GRSKD      13          Yes  Month-to-month              Yes
#
#                 PaymentMethod  MonthlyCharges TotalCharges Churn
# 1                Mailed check           56.95       1889.5    No
# 3   Bank transfer (automatic)           42.30      1840.75    No
# 6     Credit card (automatic)           89.10       1949.4    No
# 9   Bank transfer (automatic)           56.15      3487.95    No
# 10               Mailed check           49.95       587.45    No

# %%
b['Contract'].value_counts()
# groups, counts, sorts
# Out:
# Contract
# Month-to-month    1137
# Two year           824
# One year           664
# Name: count, dtype: int64

# %% [markdown]
# ##Quiz

# %%
user = pd.read_csv("/content/Users.csv")
rest = pd.read_csv("/content/Restaurant.csv")
order = pd.read_csv("/content/Orders.csv")
menu = pd.read_csv("/content/Menu.csv")
food = pd.read_csv("/content/Food.csv")

# %%
user.head()
# Out:
#    User_id               Name  Age  Gender Marital Status Occupation
# 0        1    Claire Ferguson   20  Female         Single    Student
# 1        2     Jennifer Young   24  Female         Single    Student
# 2        3  Jermaine Roberson   22    Male         Single    Student
# 3        4   Rachel Carpenter   22  Female         Single    Student
# 4        5       Shawn Parker   22    Male         Single    Student

# %%
user['Occupation'].value_counts()
# Out:
# Occupation
# Student           53357
# Employee          30408
# Self Employeed    13913
# House wife         2322
# Name: count, dtype: int64

# %%
rest.head()
# Out:
#    Restaurant_id               Name Country    City Rating     Rating_count  \
# 0         567335     AB FOODS POINT   India  Abohar     --  Too Few Ratings
# 1         531342  Janta Sweet House   India  Abohar    4.4      50+ ratings
# 2         158203  theka coffee desi   India  Abohar    3.8     100+ ratings
# 3         187912          Singh Hut   India  Abohar    3.7      20+ ratings
# 4         543530      GRILL MASTERS   India  Abohar     --  Too Few Ratings
#
#                       Cuisine
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food

# %%
rest['City'].value_counts()
# Out:
# City
# Bikaner                 1666
# Noida-1                 1427
# Indirapuram,Delhi       1279
# BTM,Bangalore           1161
# Rohini,Delhi            1135
#                         ...
# Alwarpet,Chennai           1
# BBK_Chattarpur,Delhi       1
# BBK_MayurVihar,Delhi       1
# Hampi                      1
# Manali                     1
# Name: count, Length: 821, dtype: int64

# %%
food.head()
# Out:
#   Food_id                  Item Food_Type
# 0     fd0     Aloo Tikki Burger       Veg
# 1     fd1     Veg Creamy Burger       Veg
# 2     fd2   Cheese Burst Burger       Veg
# 3     fd3  Paneer Creamy Burger       Veg
# 4     fd4        Maxican Burger       Veg

# %%
food['Food_Type'].value_counts(normalize=True)
# Out:
# Food_Type
# Veg        0.728749
# Non-veg    0.271251
# Name: proportion, dtype: float64

# %%
order.head()
# Out:
#    order_date  Sales_QTY  Sales_amount currency  User_id  Restaurant_id
# 0  2017-10-10        100         41241      INR    49226       567335.0
# 1  2018-05-08          3            -1      INR    77359       531342.0
# 2  2018-04-06          1           875      INR     5321       158203.0
# 3  2018-04-11          1           583      INR    21343       187912.0
# 4  2018-06-18          6          7176      INR    75378       543530.0

# %%
order['Sales_amount']>0
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 150276     True
# 150277     True
# 150278     True
# 150279     True
# 150280     True
# Name: Sales_amount, Length: 150281, dtype: bool

# %%
order[order['Sales_amount']>0]['Sales_amount'].mean()
# Out:
# np.float64(6635.938777157463)

# %%
user.head()
# Out:
#    User_id               Name  Age  Gender Marital Status Occupation
# 0        1    Claire Ferguson   20  Female         Single    Student
# 1        2     Jennifer Young   24  Female         Single    Student
# 2        3  Jermaine Roberson   22    Male         Single    Student
# 3        4   Rachel Carpenter   22  Female         Single    Student
# 4        5       Shawn Parker   22    Male         Single    Student

# %%
user['User_id'].nunique()
# Out:
# 100000

# %%
order.head()
# Out:
#    order_date  Sales_QTY  Sales_amount currency  User_id  Restaurant_id
# 0  2017-10-10        100         41241      INR    49226       567335.0
# 1  2018-05-08          3            -1      INR    77359       531342.0
# 2  2018-04-06          1           875      INR     5321       158203.0
# 3  2018-04-11          1           583      INR    21343       187912.0
# 4  2018-06-18          6          7176      INR    75378       543530.0

# %%
order['User_id'].nunique()
# Out:
# 77929

# %%
uo = pd.merge(user, order, on = 'User_id', how = 'right')

# %%
100000-77929
# Out:
# 22071

# %%
uo['User_id'].nunique()
# Out:
# 77929

# %%
len(set(user['User_id']) - set(order['User_id']))
# Out:
# 22071

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
# ...
